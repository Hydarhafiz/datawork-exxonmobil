# %% [markdown]
# # Model testing workbook
# This is an workbook to test students model using test dataset

# %% [markdown]
# ## Library imports

# %%
import Common.Utilities as util
import Common.Preprocessing as preprocessing
import Common.Visualization as visualization
import Common.Modeling as modeling

# %%
testDataset = util.getTestDataset()
display(testDataset)
# Out:
#         WellName      TestUsage        Date  OilRate (STB/D)  \
# 0       WELL-146  Informational  2018-01-01       463.293964
# 1       WELL-109     Allocation  2018-01-02      3907.251617
# 2       WELL-148     Allocation  2018-01-03      4360.958881
# 3       WELL-122     Allocation  2018-01-04      4020.746496
# 4       WELL-122  Informational  2018-01-05      4298.537852
# ..           ...            ...         ...              ...
# 459  WELL-107ST2     Allocation  2019-12-23      3017.641751
# 460     WELL-148  Informational  2019-12-26      2116.490627
# 461    WELL-145A     Allocation  2019-12-30      4283.788575
# 462     WELL-109     Allocation  2019-12-31      3493.660878
# 463     WELL-114     Allocation  2019-12-31      5789.334799
#
#      WaterRate (STB/D)  GasRate (MSCF/D)  GasLiftRate (MSCF/D)  \
# 0           711.988384          3.925202              4.530505
# 1           435.901322          5.772112              5.050984
# ...

# %% [markdown]
# ## Data Pre-processing

# %%
testDataset = preprocessing.getSluggingClass(testDataset, WHPFluctuationTreshold=10)
testDataset.head()

# %% [markdown]
# ## Load saved model

# %%
model = modeling.loadModel('your_best_model_name.pkl')

# %% [markdown]
# ## Model evaluation
